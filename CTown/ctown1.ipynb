# %%
import sys
sys.path.append("C:/Users/user/meepc")
import numpy as np
import pandas as pd
from models import Hankel,Rank,Cluster,Meepc
import warnings
warnings.simplefilter('ignore')
import math
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
hankel = Hankel()
rank = Rank()
cluster = Cluster()
meepc = Meepc.MEEPC()
scaler = StandardScaler()

# %%
df1 = pd.read_csv('~/data/ctown/dataset03.csv')
# df1 = df1.iloc[:-1 , :]

# %%
df2 = pd.read_csv('~/data/ctown/dataset04.csv')
# df2 = df2.iloc[:-7,:]
df2_normal = df2[df2['ATT_FLAG']==0]
df2_attack = df2[df2['ATT_FLAG']==1]

# %%
df = pd.concat((df1,df2_normal),axis=0)

# %%
sensors = [col for col in df.columns if col not in ['DATETIME','ATT_FLAG']]

# %%
X_train = pd.DataFrame(index=df.index, columns=sensors, data=scaler.fit_transform(df[sensors]))
Y_train = df.loc[:,'ATT_FLAG']

# %%
X_train
# Out:
#           L_T1      L_T2      L_T3      L_T4      L_T5      L_T6      L_T7
# 0    -1.810652 -0.840399 -1.489684 -1.438753 -0.125827 -0.299891 -2.102859  \
# 1    -1.891658 -0.867565 -0.824829 -1.366330  0.513682  0.702713 -1.754244
# 2    -1.968762 -0.883198 -0.091921 -0.577770  1.123162  0.731687 -1.280055
# 3    -1.958116 -0.867475  0.693507  0.327115  1.636865  0.731687 -0.127985
# 4    -1.832527 -0.813155  1.524846  1.560727  1.028078  0.731687  1.359430
# ...        ...       ...       ...       ...       ...       ...       ...
# 4172 -0.026020 -0.622019 -0.519318 -0.979847  1.456856 -2.422136 -1.347590
# 4173 -0.367893 -0.492759 -1.152625 -1.202467  1.280082 -1.971590 -1.612310
# 4174 -0.643058 -0.356696 -1.844844 -2.000190 -0.066119 -1.295771 -1.732637
# 4175 -0.968254 -0.519972 -1.285178 -2.853569 -1.439516 -1.521044 -2.310208
# 4176 -1.318464 -0.792099 -0.696055 -1.554950 -1.589094 -1.352089 -2.550863
#
#          F_PU1  S_PU1     F_PU2  ...    P_J300    P_J256    P_J289    P_J415
# 0    -0.192322    0.0  0.701055  ... -0.485068  0.969072 -0.467118  0.198329  \
# 1    -0.182644    0.0  0.703361  ... -0.486352  1.186900 -0.470150  0.423304
# 2    -0.249670    0.0  0.687387  ... -0.484604  1.376971 -0.470137  0.513959
# 3    -0.333661    0.0  0.667368  ... -0.451086  1.558821 -0.437744  0.705006
# 4    -0.355917    0.0  0.662064  ... -0.395961  1.780926 -0.383674  1.024098
# ...        ...    ...       ...  ...       ...       ...       ...       ...
# 4172  1.901208    0.0 -1.641849  ... -0.123946 -1.108734 -0.143233  0.189478
# 4173  1.805874    0.0 -1.641849  ... -0.018536 -1.277789 -0.040691  0.099141
# 4174  1.963771    0.0 -1.641849  ... -0.360210  0.735496 -0.340993  0.014118
# 4175  1.895249    0.0 -1.641849  ... -0.730962  0.796970 -0.729189  2.778709
# 4176  1.926034    0.0 -1.641849  ... -0.778215  1.143355 -0.780460  3.081605
#
#         P_J302    P_J306    P_J307    P_J317     P_J14    P_J422
# 0    -1.258253  0.754636 -1.256119 -0.150254 -1.034333 -0.359477
# 1    -1.270108  0.771354 -1.267867 -0.140255 -1.042174 -0.371926
# 2    -1.100738  0.955519 -1.097261  0.847781 -1.042107 -0.371820
# 3     0.355822 -0.980130  0.350843  1.572762 -1.019584 -0.336060
# 4     0.396924 -0.972501  0.391854  1.653455 -0.990238 -0.289469
# ...        ...       ...       ...       ...       ...       ...
# 4172 -1.360548  0.723200 -1.357927 -0.354694 -0.918065 -0.174880
# 4173  0.213483 -1.362938  0.206009 -0.194622 -0.844885 -0.058695
# 4174  0.000592 -1.492194 -0.005821 -0.347161 -0.965277 -0.249839
# 4175  0.070801 -1.547303  0.064038 -0.283132 -1.130522 -0.512194
# 4176 -1.426227  0.620997 -1.421025 -0.113645 -1.184816 -0.598397
#
# [12446 rows x 43 columns]

# %%
df_test = pd.read_csv('~/data/ctown/test_dataset.csv')
df_test = pd.concat((df_test,df2_attack),axis=0)
# df_test = df_test.iloc[:-19,:]

# %%
X_test = pd.DataFrame(index=df_test.index, columns=sensors, data=scaler.fit_transform(df_test[sensors]))
Y_test = df_test.loc[:,'ATT_FLAG']

# %%
X_test
# Out:
#           L_T1      L_T2      L_T3      L_T4      L_T5      L_T6      L_T7
# 0    -1.665191 -0.749711 -0.294490 -0.524638  1.521278  0.737676  1.194776  \
# 1    -1.697547 -0.763579  0.485787 -0.524638  1.480516  0.737676  1.801174
# 2    -1.527678 -0.721976  1.221897 -0.253726  0.773981 -1.229027 -0.090788
# 3    -1.357809 -0.562501  1.413286  0.757679  0.094621 -2.096689 -0.915490
# 4    -1.228385 -0.250484  1.089398  1.299503 -0.543978  0.043546  0.139643
# ...        ...       ...       ...       ...       ...       ...       ...
# 4032 -1.940216  0.318080 -0.265045 -0.488516  1.697911  0.737676  0.576250
# 4033 -1.851237  0.234876  0.441621  0.306159  0.760394  0.737676  1.182648
# 4034 -1.721814  0.179406  1.133564  0.631253 -0.190710  0.737676  2.007350
# 4035 -1.511500  0.227942  1.663564  1.371746 -0.910832 -0.881961  0.430714
# 4036 -1.260741  0.588495  1.369119  1.118895 -1.522257 -2.443754 -0.915490
#
#          F_PU1     S_PU1     F_PU2  ...    P_J300    P_J256    P_J289
# 0    -0.106633  0.062366  0.726428  ... -0.449812  1.282528 -0.435432  \
# 1    -0.188567  0.062366  0.703585  ... -0.453321  1.269846 -0.438965
# 2    -0.283042  0.062366  0.677246  ... -0.397184  1.418562 -0.382440
# 3    -0.288059  0.062366  0.675848  ...  0.108044 -0.379860  0.090962
# 4    -0.454435  0.062366  0.629463  ...  1.178145 -0.430585  1.182611
# ...        ...       ...       ...  ...       ...       ...       ...
# 4032 -0.138404  0.062366  0.717570  ...  0.023839  1.164938  0.045035
# 4033 -0.232878  0.062366  0.691232  ...  0.020331  1.176467  0.041502
# 4034 -0.278862  0.062366  0.678412  ...  0.027348  1.531540  0.045035
# 4035 -0.356616  0.062366  0.656735  ...  0.462405 -0.319913  0.447779
# 4036 -0.425173  0.062366  0.637621  ...  1.388657 -0.430585  1.394582
#
#         P_J415    P_J302    P_J306    P_J307    P_J317     P_J14    P_J422
# 0     0.219764 -1.070652  0.881118 -1.074422  0.560724 -0.908502 -0.344563
# 1     0.287779  0.256408 -1.018191  0.251294  0.979330 -0.904267 -0.337055
# 2     0.565068  0.907763 -1.059068  0.925318 -1.528905 -0.868269 -0.273243
# 3     0.783499  0.370040 -1.097951  0.362955  0.490956 -0.656512  0.102122
# 4    -1.738267  0.558750 -1.096954  0.551763  0.484149 -0.061477  1.156900
# ...        ...       ...       ...       ...       ...       ...       ...
# 4032  0.506210 -1.103118  0.820300 -1.108936  0.426293 -0.631102  0.147166
# 4033  0.383260  0.278729 -1.172727  0.273626  0.945297 -0.624749  0.158427
# 4034  0.550681  0.891530 -1.149796  0.909077 -1.302586 -0.622631  0.162181
# 4035  0.826662  0.997046 -1.157772  1.014647 -1.479557 -0.444756  0.477488
# 4036 -1.776198  0.530342 -1.155778  0.525370  0.581144  0.057106  1.367105
#
# [2581 rows x 43 columns]

# %%
lag =  60
stride = 0.5

# %%
labels = hankel.fit(np.array(Y_test),lag,stride)
actual_labels = np.any(labels>0,axis=0).astype(int)
isatt=np.any(labels>0,axis=0)
att_indices = np.where(isatt)[0]
att_indices
# Out:
# array([ 8,  9, 10, 11, 12, 20, 21, 22, 23, 27, 28, 29, 30, 31, 32, 39, 40,
#        41, 42, 43, 44, 51, 52, 53, 54, 55, 63, 64, 65, 68, 69, 70, 71, 72,
#        73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84], dtype=int64)

# %%
len(att_indices)
# Out:
# 46

# %%
def find_threshold(radii_n,radii_a):
    label = [1]*len(radii_n) + [-1]*len(radii_a)
    label = np.array(label)
    radiis = np.array(list(radii_n)+list(radii_a))
    indices = np.argsort(radiis)
    label = label[indices]
    pos_temp = (1+label)//2
    neg_temp = (1-label)//2
    tp = np.cumsum(pos_temp)
    fp = np.cumsum(neg_temp)
    fn = tp[-1] - tp
    fmeas = 2*tp / (2*tp + fp + fn)
    # print(fmeas)
    idx = np.argmax(fmeas)
    # print(indices[idx])
    return radiis[indices[idx]]

# %%
scores=[]
for sens in range(len(X_train.columns)):
    X = X_train.iloc[:,sens].values
    X = hankel.fit(X,lag,stride)
    X=X.T 
    kmeans,optimal_k = cluster.fit(X)
    # optimal_k = 16
    # kmeans = KMeans(n_clusters=optimal_k, init='k-means++')
    kmeans.fit(X)
    print(optimal_k)
    # radiis_normal = []
    threshold_clusters = []
    weights=[]
    centers=[]
    clusters_R=[]
    clusters_V=[]
    for i in range(optimal_k):
        cluster_ = X[np.where(kmeans.labels_ == i)[0]]
        r = rank.fit(cluster_)
        clusters_R.append(r)
        if(optimal_k==1):
            print("r: "+str(r))
        U,Sigma,VT = np.linalg.svd(cluster_)
        V = VT.T
        clusters_V.append(V)
        cluster_ = np.matmul(cluster_,V[:,:r])
        weight,center = meepc.fit(cluster_)
        weights.append(weight)
        centers.append(center)
        var1=np.square(cluster_-center)
        var2=np.matmul(weight,var1.T)
        threshold_clusters.append(np.max(np.sqrt(var2)))
        # radiis_normal.append(np.sqrt(var2))
    print(threshold_clusters)
    
    # X_attack = df_attack.iloc[:,sens].values
    # X_att = hankel.fit(X_attack,1,0.5)
    # X_att=X_att.T 
    # radiis_attack = []
    # for i in range(optimal_k):
    #     cluster_ = np.matmul(X_att,clusters_V[i][:,:clusters_R[i]])
    #     var1=np.square(cluster_-centers[i])
    #     var2=np.matmul(weights[i],var1.T)
    #     radiis_attack.append(np.sqrt(var2))
    # threshold_clusters = [0]*optimal_k
    # for i in range(optimal_k):
    #     threshold_clusters[i] = find_threshold(radiis_normal[i],radiis_attack[i])

    Xtest = X_test.iloc[:,sens].values
    Xtest=hankel.fit(Xtest,lag,stride)  #size -> 1800x274
    Xtest=Xtest.T  
    distances=[]
    for i in range(optimal_k):
        Xtest_cluster=np.matmul(Xtest,clusters_V[i][:,:clusters_R[i]]) 
        var1=np.square(Xtest_cluster-centers[i])
        var2=np.matmul(weights[i],var1.T)
        distance=np.sqrt(var2)
        distances.append(distance)

    stacked_arr=np.vstack(distances)
    distances_arr=np.transpose(stacked_arr)
    check_anamoly=threshold_clusters-distances_arr     # positive = inside cluster | negative = outside cluster  
    predicted_labels = np.all(check_anamoly<0,axis=1).astype(int)
    #check for if any datapoint is coming inside the cluster
    is_positive=np.any(check_anamoly>0,axis=1)
    #indices of those rows
    positive_indices=np.where(is_positive)[0]
    # calculate accuracy
    accuracy = accuracy_score(actual_labels, predicted_labels)
    print('Accuracy: ',accuracy)
    # calculate precision
    precision = precision_score(actual_labels, predicted_labels)
    print('Precision: ',precision)
    # calculate recall
    recall = recall_score(actual_labels, predicted_labels)
    print('Recall: ',recall)
    # calculate F1-score
    f1 = f1_score(actual_labels, predicted_labels)
    print('F1score: ',f1)
    # calculate AUC
    auc = roc_auc_score(actual_labels, predicted_labels)
    print('ROC AUC Score: ',auc)
    scores.append([accuracy,precision,recall,f1])
    # cnt=0
    # print("sensor ->",sens)
    # for i in range(len(Xtest)):
    #     if i not in positive_indices:
    #             print(i,end=' ')
    #             if i in list(att_indices):
    #                 cnt+=1
    # print("count",cnt)
    print("\nnext")
    # print(threshold_clusters)
    # print(distances_arr)
# Out:
# 3
# [1.0019281384606735, 0.9999972593482104, 0.9999986069890473]
# Accuracy:  0.611764705882353
# Precision:  0.7241379310344828
# Recall:  0.45652173913043476
# F1score:  0.5599999999999999
# ROC AUC Score:  0.6256967670011149
#
# next
# 8
# [0.999997537567033, 0.9999999223452275, 1.0055308802775593, 1.0047657635831115, 1.0075135122181653, 0.9999969218831458, 1.000003479018612, 1.0000014269513207]
# Accuracy:  0.6
# Precision:  0.8
# Recall:  0.34782608695652173
# F1score:  0.48484848484848486
# ROC AUC Score:  0.6226309921962095
#
# next
# 1
# r: 15
# [1.0017133317606879]
# Accuracy:  0.5411764705882353
# Precision:  0.5777777777777777
# Recall:  0.5652173913043478
# F1score:  0.5714285714285713
# ROC AUC Score:  0.5390189520624302
#
# next
# 1
# r: 33
# [1.003858628300113]
# Accuracy:  0.5647058823529412
# Precision:  0.6956521739130435
# Recall:  0.34782608695652173
# F1score:  0.46376811594202894
# ROC AUC Score:  0.5841694537346711
#
# next
# 1
# r: 12
# [1.0178905202926796]
# Accuracy:  0.5411764705882353
# Precision:  0.7333333333333333
# Recall:  0.2391304347826087
# F1score:  0.36065573770491804
# ROC AUC Score:  0.5682831661092531
#
# next
# 7
# [1.0000334827901323, 1.0098264690997902, 1.0000428461400266, 1.0026541084293572, 1.0000542341327627, 1.0033501399538653, 1.0055312370397285]
# Accuracy:  0.4823529411764706
# Precision:  1.0
# Recall:  0.043478260869565216
# F1score:  0.08333333333333333
# ROC AUC Score:  0.5217391304347826
#
# next
# 8
# [1.007502051750873, 1.001759989858745, 1.0050108696353466, 1.016444978686427, 1.0013036138663094, 1.0004822785278795, 1.0011663283310033, 1.0013435531586299]
# Accuracy:  0.4823529411764706
# Precision:  0.625
# Recall:  0.10869565217391304
# F1score:  0.18518518518518517
# ROC AUC Score:  0.5158862876254181
#
# next
# 4
# [0.9999981288194859, 1.0031692361274178, 1.0058256616397627, 1.00281655174046]
# Accuracy:  0.5411764705882353
# Precision:  0.7333333333333333
# Recall:  0.2391304347826087
# F1score:  0.36065573770491804
# ROC AUC Score:  0.5682831661092531
#
# next
# 1
# r: 59
# [nan]
# Accuracy:  0.4588235294117647
# Precision:  0.0
# Recall:  0.0
# F1score:  0.0
# ROC AUC Score:  0.5
#
# next
# 4
# [0.9999986959009605, 1.0039888952884486, 1.0055293614993737, 1.002639799864957]
# Accuracy:  0.5411764705882353
# Precision:  0.6842105263157895
# Recall:  0.2826086956521739
# F1score:  0.39999999999999997
# ROC AUC Score:  0.5643812709030099
#
# next
# 1
# r: 15
# [1.0176540955689397]
# Accuracy:  0.5058823529411764
# Precision:  1.0
# Recall:  0.08695652173913043
# F1score:  0.16
# ROC AUC Score:  0.5434782608695652
#
# next
# 1
# r: 59
# [nan]
# Accuracy:  0.4588235294117647
# Precision:  0.0
# Recall:  0.0
# F1score:  0.0
# ROC AUC Score:  0.5
#
# next
# 1
# r: 59
# [nan]
# Accuracy:  0.4588235294117647
# Precision:  0.0
# Recall:  0.0
# F1score:  0.0
# ROC AUC Score:  0.5
#
# next
# 1
# r: 29
# [1.0046242378587384]
# Accuracy:  0.5176470588235295
# Precision:  0.5510204081632653
# Recall:  0.5869565217391305
# F1score:  0.568421052631579
# ROC AUC Score:  0.5114269788182831
#
# next
# 1
# r: 26
# [1.0092537118049103]
# Accuracy:  0.49411764705882355
# Precision:  1.0
# Recall:  0.06521739130434782
# F1score:  0.12244897959183672
# ROC AUC Score:  0.532608695652174
#
# next
# 1
# r: 59
# [nan]
# Accuracy:  0.4588235294117647
# Precision:  0.0
# Recall:  0.0
# F1score:  0.0
# ROC AUC Score:  0.5
#
# next
# 1
# r: 59
# [nan]
# Accuracy:  0.4588235294117647
# Precision:  0.0
# Recall:  0.0
# F1score:  0.0
# ROC AUC Score:  0.5
#
# next
# 8
# [1.0000032212704013, 0.0, 0.0, 0.9999963801088454, 0.0, 1.0198357601431058, 0.0, 0.0]
# Accuracy:  0.4588235294117647
# Precision:  0.0
# Recall:  0.0
# F1score:  0.0
# ROC AUC Score:  0.5
#
# next
# 1
# r: 16
# [1.0284074926232287]
# Accuracy:  0.4588235294117647
# Precision:  0.0
# Recall:  0.0
# F1score:  0.0
# ROC AUC Score:  0.5
#
# next
# 3
# [1.000772777836937, 1.0118087504402449, 1.017410486023964]
# Accuracy:  0.4235294117647059
# Precision:  0.2857142857142857
# Recall:  0.043478260869565216
# F1score:  0.07547169811320756
# ROC AUC Score:  0.4576365663322185
#
# next
# 1
# r: 57
# [1.0041290966317222]
# Accuracy:  0.5294117647058824
# Precision:  0.8
# Recall:  0.17391304347826086
# F1score:  0.2857142857142857
# ROC AUC Score:  0.5613154960981047
#
# next
# 7
# [0.9999975909047892, 1.0008122278755438, 1.0044676418329204, 1.0064891492403105, 1.0000010838994946, 1.0102645400078085, 1.002427862569732]
# Accuracy:  0.5647058823529412
# Precision:  0.7647058823529411
# Recall:  0.2826086956521739
# F1score:  0.4126984126984127
# ROC AUC Score:  0.5900222965440356
#
# next
# 1
# r: 33
# [1.0085444679540012]
# Accuracy:  0.5058823529411764
# Precision:  1.0
# Recall:  0.08695652173913043
# F1score:  0.16
# ROC AUC Score:  0.5434782608695652
#
# next
# 1
# r: 59
# [nan]
# Accuracy:  0.4588235294117647
# Precision:  0.0
# Recall:  0.0
# F1score:  0.0
# ROC AUC Score:  0.5
#
# next
# 1
# r: 59
# [nan]
# Accuracy:  0.4588235294117647
# Precision:  0.0
# Recall:  0.0
# F1score:  0.0
# ROC AUC Score:  0.5
#
# next
# 3
# [1.006012367214272, 1.0055865258636907, 1.0065933993570588]
# Accuracy:  0.5058823529411764
# Precision:  0.6
# Recall:  0.2608695652173913
# F1score:  0.36363636363636365
# ROC AUC Score:  0.5278706800445931
#
# next
# 1
# r: 56
# [1.0026072037215161]
# Accuracy:  0.6
# Precision:  0.9285714285714286
# Recall:  0.2826086956521739
# F1score:  0.4333333333333333
# ROC AUC Score:  0.6284838350055741
#
# next
# 4
# [1.0000000000001115, 0.0, 0.0, 0.0]
# Accuracy:  0.4588235294117647
# Precision:  0.0
# Recall:  0.0
# F1score:  0.0
# ROC AUC Score:  0.5
#
# next
# 1
# r: 6
# [1.00001799228164]
# Accuracy:  0.4588235294117647
# Precision:  0.0
# Recall:  0.0
# F1score:  0.0
# ROC AUC Score:  0.5
#
# next
# 8
# [1.0002985209026518, 1.0092492684808396, 0.9999993977430549, 1.0000044789392462, 1.0001171255159405, 1.006219833509195, 1.0015389971679494, 1.0074693271994999]
# Accuracy:  0.6
# Precision:  1.0
# Recall:  0.2608695652173913
# F1score:  0.41379310344827586
# ROC AUC Score:  0.6304347826086957
#
# next
# 1
# r: 15
# [1.0157628372902425]
# Accuracy:  0.4823529411764706
# Precision:  1.0
# Recall:  0.043478260869565216
# F1score:  0.08333333333333333
# ROC AUC Score:  0.5217391304347826
#
# next
# 8
# [1.0045905560412878, 1.0001840078153994, 0.9999987509806145, 1.0039488839397308, 1.0043641128783782, 1.0020630635731256, 1.0008298369514876, 1.0126416005612053]
# Accuracy:  0.5647058823529412
# Precision:  0.6956521739130435
# Recall:  0.34782608695652173
# F1score:  0.46376811594202894
# ROC AUC Score:  0.5841694537346711
#
# next
# 4
# [1.03433908778182, 1.0061052398403991, 1.0047441317990815, 0.9999956524554792]
# Accuracy:  0.5411764705882353
# Precision:  0.7058823529411765
# Recall:  0.2608695652173913
# F1score:  0.380952380952381
# ROC AUC Score:  0.5663322185061316
#
# next
# 8
# [1.0024423996462917, 1.0013363904814228, 1.0052188309628176, 1.0059603710196872, 1.0047207011994443, 1.0093654392363507, 1.0054045412515273, 1.0080448104969175]
# Accuracy:  0.5764705882352941
# Precision:  0.75
# Recall:  0.32608695652173914
# F1score:  0.45454545454545453
# ROC AUC Score:  0.5989409141583055
#
# next
# 1
# r: 31
# [1.0047099820296062]
# Accuracy:  0.5647058823529412
# Precision:  0.5918367346938775
# Recall:  0.6304347826086957
# F1score:  0.6105263157894736
# ROC AUC Score:  0.5588071348940915
#
# next
# 8
# [1.005534188524701, 1.0024587001675855, 1.00106198598776, 0.9999972565007782, 1.0038193662587294, 1.0027684418429983, 1.0017362913343735, 1.00268409764389]
# Accuracy:  0.611764705882353
# Precision:  0.8823529411764706
# Recall:  0.32608695652173914
# F1score:  0.47619047619047616
# ROC AUC Score:  0.637402452619844
#
# next
# 8
# [1.0055360849755985, 1.005618772285321, 1.01077080704315, 1.0048250292542376, 1.0096110691717108, 1.002251380645323, 1.0060824241603414, 1.0049888204845532]
# Accuracy:  0.47058823529411764
# Precision:  0.6666666666666666
# Recall:  0.043478260869565216
# F1score:  0.08163265306122448
# ROC AUC Score:  0.5089186176142698
#
# next
# 1
# r: 32
# [1.0003207873288138]
# Accuracy:  0.6470588235294118
# Precision:  0.8333333333333334
# Recall:  0.43478260869565216
# F1score:  0.5714285714285714
# ROC AUC Score:  0.6661092530657748
#
# next
# 7
# [1.003942455328446, 1.0053071099707385, 0.9999966184367518, 1.0104097740765337, 0.999995416314671, 1.001153034486916, 1.002473781284293]
# Accuracy:  0.5176470588235295
# Precision:  0.631578947368421
# Recall:  0.2608695652173913
# F1score:  0.3692307692307692
# ROC AUC Score:  0.5406911928651059
#
# next
# 1
# r: 35
# [1.0055284604155843]
# Accuracy:  0.5882352941176471
# Precision:  0.6410256410256411
# Recall:  0.5434782608695652
# F1score:  0.5882352941176471
# ROC AUC Score:  0.5922519509476031
#
# next
# 8
# [1.0074710713708845, 1.0011475644214154, 1.0005865839616321, 1.002451489494367, 1.0185119478615863, 1.0163857335220932, 1.0149470413692987, 1.0000022003471116]
# Accuracy:  0.49411764705882355
# Precision:  0.8
# Recall:  0.08695652173913043
# F1score:  0.1568627450980392
# ROC AUC Score:  0.5306577480490523
#
# next
# 8
# [1.0000049883057778, 0.9999982299906526, 1.0000641372490555, 1.0021057915748055, 1.0058942882781605, 1.0187540875596273, 1.0045450693733735, 1.0113346262344343]
# Accuracy:  0.6
# Precision:  0.9285714285714286
# Recall:  0.2826086956521739
# F1score:  0.4333333333333333
# ROC AUC Score:  0.6284838350055741
#
# next
# 6
# [1.0104917277228522, 1.001820586397687, 1.0089528009957682, 1.000558484889345, 1.0196554493391417, 1.0009497410007784]
# Accuracy:  0.5764705882352941
# Precision:  0.8125
# Recall:  0.2826086956521739
# F1score:  0.41935483870967744
# ROC AUC Score:  0.6028428093645486
#
# next

# %%
print("mean ",np.asarray(scores).mean(axis=0))
print("min ",np.asarray(scores).min(axis=0))
print("max",np.asarray(scores).max(axis=0))
print("median ",np.median(np.asarray(scores),axis=0 ))
# Out:
# mean  [0.52175103 0.56843854 0.20070779 0.26871597]
# min  [0.42352941 0.         0.         0.        ]
# max [0.64705882 1.         0.63043478 0.61052632]
# median  [0.51764706 0.69565217 0.23913043 0.36065574]
