# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('~/data/ctown/dataset04.csv')
df_normal=pd.read_csv('~/data/ctown/dataset03.csv')
df
# Out:
#          DATETIME  L_T1  L_T2  L_T3  L_T4  L_T5  L_T6  L_T7   F_PU1  S_PU1  \
# 0     04/07/16 00  2.44  5.24  3.19  4.10  2.86  5.50  4.39   93.63      1
# 1     04/07/16 01  2.66  4.53  3.20  4.18  3.29  5.44  4.53   89.41      1
# 2     04/07/16 02  3.11  3.66  3.66  4.21  3.87  5.15  3.22   89.88      1
# 3     04/07/16 03  3.62  3.04  4.17  4.04  3.56  4.98  2.40   88.10      1
# 4     04/07/16 04  4.08  2.68  4.73  3.20  3.11  5.39  3.46   87.01      1
# ...           ...   ...   ...   ...   ...   ...   ...   ...     ...    ...
# 4172  24/12/16 20  2.65  2.37  3.85  3.04  3.82  4.94  2.19  120.08      1
# 4173  24/12/16 21  2.24  2.56  3.42  2.92  3.69  5.02  1.97  119.12      1
# 4174  24/12/16 22  1.91  2.76  2.95  2.49  2.70  5.14  1.87  120.71      1
# 4175  24/12/16 23  1.52  2.52  3.33  2.03  1.69  5.10  1.39  120.02      1
# 4176  25/12/16 00  1.10  2.12  3.73  2.73  1.58  5.13  1.19  120.33      1
#
# ...

# %%
df.loc[1727:1727+50-1, ['DATETIME','L_T7','S_PU10','F_PU10','S_PU11','F_PU11','ATT_FLAG']]
# Out:
#          DATETIME  L_T7  S_PU10  F_PU10  S_PU11  F_PU11  ATT_FLAG
# 1727  13/09/16 23  2.84       1   25.17       1   25.13         1
# 1728  14/09/16 00  3.13       0    0.00       0    0.00         1
# 1729  14/09/16 01  3.45       0    0.00       0    0.00         1
# 1730  14/09/16 02  3.95       0    0.00       0    0.00         1
# 1731  14/09/16 03  4.78       1   23.64       1   23.60         1
# 1732  14/09/16 04  3.75       1   24.67       1   24.63         1
# 1733  14/09/16 05  2.95       0    0.00       0    0.00         1
# 1734  14/09/16 06  2.87       0    0.00       0    0.00         1
# 1735  14/09/16 07  3.47       0    0.00       0    0.00         1
# 1736  14/09/16 08  4.36       1   27.06       1   27.02         1
# 1737  14/09/16 09  4.59       0    0.00       0    0.00         1
# 1738  14/09/16 10  4.50       0    0.00       0    0.00         1
# 1739  14/09/16 11  4.29       1   22.01       1   21.97         1
# ...

# %%
df.loc[2027:2027+24-1, ['DATETIME','L_T7','S_PU10','F_PU10','S_PU11','F_PU11','ATT_FLAG']]
# Out:
#          DATETIME  L_T7  S_PU10  F_PU10  S_PU11  F_PU11  ATT_FLAG
# 2027  26/09/16 11  2.41       1   31.03       0     0.0         1
# 2028  26/09/16 12  2.66       1   31.06       0     0.0         1
# 2029  26/09/16 13  2.74       1   31.05       0     0.0         1
# 2030  26/09/16 14  3.12       1   31.97       0     0.0         1
# 2031  26/09/16 15  3.84       1   31.94       0     0.0         1
# 2032  26/09/16 16  4.50       1   31.30       0     0.0         1
# 2033  26/09/16 17  3.88       0    0.00       0     0.0         1
# 2034  26/09/16 18  2.53       1   30.89       0     0.0         1
# 2035  26/09/16 19  2.96       1   31.02       0     0.0         1
# 2036  26/09/16 20  3.14       1   30.23       0     0.0         1
# 2037  26/09/16 21  3.52       1   30.75       0     0.0         1
# 2038  26/09/16 22  3.35       1   30.82       0     0.0         1
# 2039  26/09/16 23  3.02       1   30.82       0     0.0         1
# ...

# %%
df[df['DATETIME']=='26/11/2016 17'].index
# Out:
# Int64Index([], dtype='int64')

# %%
df.loc[2027:2027+24-1, ['DATETIME','L_T7','S_PU10','F_PU10','S_PU11','F_PU11','ATT_FLAG']].mean()
# Out:
# /var/folders/j8/y6fbcd556gz5zc9j5h889ts40000gn/T/ipykernel_12826/3319458662.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.loc[2027:2027+24-1, ['DATETIME','L_T7','S_PU10','F_PU10','S_PU11','F_PU11','ATT_FLAG']].mean()
# L_T7         3.344583
# S_PU10       0.750000
# F_PU10      23.240417
# S_PU11       0.000000
# F_PU11       0.000000
# ATT_FLAG     1.000000
# dtype: float64

# %% [markdown]
# # attack 3

# %%
df_normal.loc[:,['DATETIME','L_T1','S_PU1','F_PU1','S_PU2','F_PU2','P_J269','ATT_FLAG']].mean()
# Out:
# /var/folders/j8/y6fbcd556gz5zc9j5h889ts40000gn/T/ipykernel_12826/2482691993.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_normal.loc[:,['DATETIME','L_T1','S_PU1','F_PU1','S_PU2','F_PU2','P_J269','ATT_FLAG']].mean()
# L_T1          2.676905
# S_PU1         1.000000
# F_PU1       100.926032
# S_PU2         0.730624
# F_PU2        69.464357
# P_J269       32.369772
# ATT_FLAG      0.000000
# dtype: float64

# %%
df.loc[2337:2337+59, ['DATETIME','L_T1','S_PU1','F_PU1','S_PU2','F_PU2','P_J269','ATT_FLAG']].mean()
# Out:
# /var/folders/j8/y6fbcd556gz5zc9j5h889ts40000gn/T/ipykernel_12826/2778037769.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.loc[2337:2337+59, ['DATETIME','L_T1','S_PU1','F_PU1','S_PU2','F_PU2','P_J269','ATT_FLAG']].mean()
# L_T1         4.266833
# S_PU1        1.000000
# F_PU1       89.805167
# S_PU2        1.000000
# F_PU2       89.821167
# P_J269      38.300667
# ATT_FLAG     1.000000
# dtype: float64

# %% [markdown]
# # attack 5
