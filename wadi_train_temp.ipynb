# %%
import pandas as pd

# %%
df=pd.read_csv('wadi_data/WADI_14days.csv')

# %%
# df['period'] = df[['Date','Time']].agg(' '.join, axis=1)
df.head()
# Out:
#    Row       Date     Time  \
# 0    1  9/25/2017  00:00.0
# 1    2  9/25/2017  00:01.0
# 2    3  9/25/2017  00:02.0
# 3    4  9/25/2017  00:03.0
# 4    5  9/25/2017  00:04.0
#
#    \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_001_PV  \
# 0                                            171.155
# 1                                            171.155
# 2                                            171.155
# 3                                            171.155
# 4                                            171.155
#
#    \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_002_PV  \
# 0                                           0.619473
# 1                                           0.619473
# 2                                           0.619473
# 3                                           0.607477
# 4                                           0.607477
#
#    \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_003_PV  \
# 0                                            11.5759
# ...

# %%
df.drop(columns=['Row','Time'],inplace=True)

# %%
df.head()
# Out:
#         Date  \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_001_PV  \
# 0  9/25/2017                                            171.155
# 1  9/25/2017                                            171.155
# 2  9/25/2017                                            171.155
# 3  9/25/2017                                            171.155
# 4  9/25/2017                                            171.155
#
#    \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_002_PV  \
# 0                                           0.619473
# 1                                           0.619473
# 2                                           0.619473
# 3                                           0.607477
# 4                                           0.607477
#
#    \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_003_PV  \
# 0                                            11.5759
# 1                                            11.5759
# 2                                            11.5759
# ...

# %%
df.Date=pd.to_datetime(df.Date)
df.Date
# Out:
# 0         2017-09-25
# 1         2017-09-25
# 2         2017-09-25
# 3         2017-09-25
# 4         2017-09-25
#              ...
# 1048566   2017-10-07
# 1048567   2017-10-07
# 1048568   2017-10-07
# 1048569   2017-10-07
# 1048570   2017-10-07
# Name: Date, Length: 1048571, dtype: datetime64[ns]

# %%
df.set_index('Date',drop=True,inplace=True)

# %%
df_temp=df
std_dev = df_temp.std(numeric_only=True)
std_dev
# Out:
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_001_PV                13.918740
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_002_PV                 0.059885
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_003_PV                 0.172156
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_004_PV                18.053601
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_005_PV                 0.048550
#                                                                             ...
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\3_P_003_STATUS               0.000000
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\3_P_004_STATUS               0.000000
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\LEAK_DIFF_PRESSURE           5.939725
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\PLANT_START_STOP_LOG         0.000000
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\TOTAL_CONS_REQUIRED_FLOW     0.444156
# Length: 127, dtype: float64

# %%
lii=[i for i in std_dev.index if std_dev[i]>=1]
lii
# Out:
# ['\\\\WIN-25J4RO10SBF\\LOG_DATA\\SUTD_WADI\\LOG_DATA\\1_AIT_001_PV',
#  '\\\\WIN-25J4RO10SBF\\LOG_DATA\\SUTD_WADI\\LOG_DATA\\1_AIT_004_PV',
#  '\\\\WIN-25J4RO10SBF\\LOG_DATA\\SUTD_WADI\\LOG_DATA\\1_LT_001_PV',
#  '\\\\WIN-25J4RO10SBF\\LOG_DATA\\SUTD_WADI\\LOG_DATA\\2_DPIT_001_PV',
#  '\\\\WIN-25J4RO10SBF\\LOG_DATA\\SUTD_WADI\\LOG_DATA\\2_FIC_101_CO',
#  '\\\\WIN-25J4RO10SBF\\LOG_DATA\\SUTD_WADI\\LOG_DATA\\2_FIC_201_CO',
#  '\\\\WIN-25J4RO10SBF\\LOG_DATA\\SUTD_WADI\\LOG_DATA\\2_FIC_301_CO',
#  '\\\\WIN-25J4RO10SBF\\LOG_DATA\\SUTD_WADI\\LOG_DATA\\2_FIC_401_CO',
#  '\\\\WIN-25J4RO10SBF\\LOG_DATA\\SUTD_WADI\\LOG_DATA\\2_FIC_501_CO',
#  '\\\\WIN-25J4RO10SBF\\LOG_DATA\\SUTD_WADI\\LOG_DATA\\2_FIC_601_CO',
#  '\\\\WIN-25J4RO10SBF\\LOG_DATA\\SUTD_WADI\\LOG_DATA\\2_LT_002_PV',
#  '\\\\WIN-25J4RO10SBF\\LOG_DATA\\SUTD_WADI\\LOG_DATA\\2_MCV_101_CO',
#  '\\\\WIN-25J4RO10SBF\\LOG_DATA\\SUTD_WADI\\LOG_DATA\\2_MCV_201_CO',
#  '\\\\WIN-25J4RO10SBF\\LOG_DATA\\SUTD_WADI\\LOG_DATA\\2_MCV_301_CO',
# ...

# %%
lii.append('\\\\WIN-25J4RO10SBF\\LOG_DATA\\SUTD_WADI\\LOG_DATA\\2_MCV_007_CO')

# %%
df_temp=df_temp.loc[:,lii]
# df_temp.plot()
df_temp
# Out:
#             \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_001_PV  \
# Date
# 2017-09-25                                            171.155
# 2017-09-25                                            171.155
# 2017-09-25                                            171.155
# 2017-09-25                                            171.155
# 2017-09-25                                            171.155
# ...                                                       ...
# 2017-10-07                                            175.855
# 2017-10-07                                            175.855
# 2017-10-07                                            175.855
# 2017-10-07                                            175.896
# 2017-10-07                                            175.896
#
#             \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_004_PV  \
# Date
# 2017-09-25                                            504.645
# 2017-09-25                                            504.645
# ...

# %%
df_temp.index
# Out:
# DatetimeIndex(['2017-09-25', '2017-09-25', '2017-09-25', '2017-09-25',
#                '2017-09-25', '2017-09-25', '2017-09-25', '2017-09-25',
#                '2017-09-25', '2017-09-25',
#                ...
#                '2017-10-07', '2017-10-07', '2017-10-07', '2017-10-07',
#                '2017-10-07', '2017-10-07', '2017-10-07', '2017-10-07',
#                '2017-10-07', '2017-10-07'],
#               dtype='datetime64[ns]', name='Date', length=1048571, freq=None)

# %%
df_temp.plot(xlim=['2017-09-25','2017-09-27'],figsize=(25,13))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## below shows the aveage values of sensor per day

# %%
df_mean_perday = df_temp.resample(rule='B').mean()

# %%
df_mean_perday
# Out:
#             \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_001_PV  \
# Date
# 2017-09-25                                         169.038099
# 2017-09-26                                         167.200752
# 2017-09-27                                         190.777035
# 2017-09-28                                         192.753438
# 2017-09-29                                         164.335747
# 2017-10-02                                         154.819132
# 2017-10-03                                         154.474423
# 2017-10-04                                         155.756624
# 2017-10-05                                         157.390203
# 2017-10-06                                         169.928214
#
#             \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_004_PV  \
# Date
# 2017-09-25                                         499.924034
# 2017-09-26                                         505.291854
# 2017-09-27                                         509.574412
# ...
